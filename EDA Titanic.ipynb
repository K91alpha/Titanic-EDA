# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Karan/Desktop/Code/CELEBAL/Titanic/Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Age']=df['Age'].astype('int')
df['Embarked']=df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.4+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(x=df['Survived'])
death_percent=round((df['Survived'].value_counts().values[0]/891)*100)
print("Out of 891 {}% people died in the accident".format(death_percent))
# Out:
# Out of 891 62% people died in the accident

# %%
print((df['Pclass'].value_counts()/891)*100)
sns.countplot(x=df['Pclass'])
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: count, dtype: float64
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print((df['Sex'].value_counts()/891)*100)
sns.countplot(x=df['Sex'])
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64
# <Axes: xlabel='Sex', ylabel='count'>

# %%
print((df['SibSp'].value_counts()/891)*100)
sns.countplot(x=df['SibSp'])
# Out:
# SibSp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: count, dtype: float64
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print((df['Parch'].value_counts()/891)*100)
sns.countplot(x=df['Parch'])
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: count, dtype: float64
# <Axes: xlabel='Parch', ylabel='count'>

# %%
print((df['Embarked'].value_counts()/891)*100)
sns.countplot(x=df['Embarked'])
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.displot(df['Age'],kde=True)
print(df['Age'].skew())
print(df['Age'].kurt())
# Out:
# 0.45956263424701577
# 0.9865867453652877

# %%
sns.boxplot(df['Age'],orient='h')
# Out:
# <Axes: >

# %%
print("People with age in between 60 and less than 70 are", df[(df['Age']>60) & (df['Age']<70)].shape[0])
print("People with age greater than 70 and less than 75 are",df[(df['Age']>=70) & (df['Age']<=75)].shape[0])
print("People with age greater than 75 are", df[df['Age']>75].shape[0])
print("-"*50)
print("People with age between 0 and 1 are ",df[df['Age']<1].shape[0])
# Out:
# People with age in between 60 and less than 70 are 15
# People with age greater than 70 and less than 75 are 6
# People with age greater than 75 are 1
# --------------------------------------------------
# People with age between 0 and 1 are  7

# %%
sns.displot(df['Fare'],kde=True)
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'],orient='h')
# Out:
# <Axes: >

# %%
print("People with fare in between $200 and $300 are ",df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("People with fare in greater than $300 are",df[df['Fare']>300].shape[0])
# Out:
# People with fare in between $200 and $300 are  17
# People with fare in greater than $300 are 3

# %% [markdown]
# # Multivariate Analysis

# %%
sns.countplot(x=df['Survived'], hue=df['Pclass'])
pd.crosstab(df['Pclass'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
sns.countplot(x=df['Survived'], hue=df['Sex'])
pd.crosstab(df['Sex'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
sns.countplot(x=df['Survived'], hue=df['Embarked'])
pd.crosstab(df['Embarked'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
plt.figure(figsize=(15,6))
sns.histplot(df[df['Survived']==0]['Age'] , kde=True)
sns.histplot(df[df['Survived']==1]['Age'] , kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(15,6))
sns.histplot(df[df['Survived']==0]['Fare'],kde=True)
sns.histplot(df[df['Survived']==1]['Fare'],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
df['family_size']=df['Parch']+df['SibSp']
def family_type(number):
    if number==0:
        return "Alone"
    elif number>0 and number<=4:
        return "Medium"
    else:
        return "Large"
df['family_type']=df['family_size'].apply(family_type)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked  family_size family_type
# 0      0         A/5 21171   7.2500        S            1      Medium
# 1      0          PC 17599  71.2833        C            1      Medium
# 2      0  STON/O2. 3101282   7.9250        S            0       Alone
# ...

# %%
df.drop(columns=['SibSp','Parch','family_size'],inplace=True)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                 Name     Sex  \
# 258          259        1      1                     Ward, Miss. Anna  female
# 0              1        0      3              Braund, Mr. Owen Harris    male
# 663          664        0      3                     Coleff, Mr. Peju    male
# 647          648        1      1  Simonius-Blumer, Col. Oberst Alfons    male
# 422          423        0      3                   Zimmerman, Mr. Leo    male
#
#      Age     Ticket      Fare Embarked family_type
# 258   35   PC 17755  512.3292        C       Alone
# 0     22  A/5 21171    7.2500        S      Medium
# 663   36     349210    7.4958        S       Alone
# 647   56      13213   35.5000        C       Alone
# 422   29     315082    7.8750        S       Alone

# %%
sns.countplot(x=df['Survived'], hue=df['family_type'])
pd.crosstab(df['family_type'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived        0     1
# family_type
# Alone        69.6  30.4
# Large        85.1  14.9
# Medium       44.0  56.0

# %% [markdown]
# # Outlier Removal

# %%
df=df[df['Age']<(df['Age'].mean()+ 3 * df['Age'].std())]
df.shape
# Out:
# (884, 10)

# %%
Q1=np.percentile(df['Fare'],25)
Q3=np.percentile(df['Fare'],75)

outlier_low=Q1-1.5*(Q3-Q1)
outlier_high=Q3+1.5*(Q3-Q1)

df=df[(df['Fare']>outlier_low) & (df['Fare']<outlier_high)]

# %% [markdown]
# # One hot Encoding

# %%
df=pd.get_dummies(data=df,columns=['Pclass','Sex','Embarked','family_type'],drop_first=True)
df.sample(5)
# Out:
#      PassengerId Survived                        Name  Age      Ticket  \
# 778          779        0     Kilgannon, Mr. Thomas J   29       36865
# 103          104        0  Johansson, Mr. Gustaf Joel   33        7540
# 757          758        0    Bailey, Mr. Percy Andrew   18       29108
# 364          365        0         O'Brien, Mr. Thomas   29      370365
# 283          284        1  Dorking, Mr. Edward Arthur   19  A/5. 10482
#
#         Fare  Pclass_2  Pclass_3  Sex_male  Embarked_Q  Embarked_S  \
# 778   7.7375     False      True      True        True       False
# 103   8.6542     False      True      True       False        True
# 757  11.5000      True     False      True       False        True
# 364  15.5000     False      True      True        True       False
# 283   8.0500     False      True      True       False        True
#
#      family_type_Large  family_type_Medium
# 778              False               False
# 103              False               False
# ...

# %% [markdown]
# # Coclusions

# %% [markdown]
# #### 1. Chances of female to survive was higher
# #### 2. Pclass 3 has most deaths
# #### 3. People going to C has more than 50% chances of survival
# #### 4. People with age range 20 - 40 had higher chance of not Surviving
# #### 5. People travelling with smaller families had a greater chance of survival when compared to large families
